# %%
from mydataset import MyDataset

# %%
nell = MyDataset('transE_NELL995')

# %%
nell.plot_degree(
    result_type='tail',
    head_degree_type='none',
    tail_degree_type='all',
    save_path='tail_all.png'
)

# %%
nell.get_degree_dist()

# %%
yago = MyDataset('transE_YAGO')

# %%
yago.plot_degree(
    result_type='head',
    head_degree_type='none',
    tail_degree_type='all',
    save_path='tail_all.png'
)

# %%
yago.get_degree_dist()

# %%
wn18 = MyDataset('transE_WN18')

# %%
wn18.plot_degree(
    result_type='head',
    head_degree_type='none',
    tail_degree_type='all',
    save_path='tail_all.png'
)

# %%
wn18.get_degree_dist()
